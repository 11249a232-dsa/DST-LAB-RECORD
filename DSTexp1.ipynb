# %% [markdown]
# <a href="https://colab.research.google.com/github/11249a232-dsa/DST-LAB-RECORD/blob/main/DSTexp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# 1️⃣ Array Creation
a = np.array([1, 2, 3, 4, 5])
b = np.arange(1, 10, 2)
c = np.linspace(0, 1, 5)
d = np.zeros((2, 3))
e = np.ones((2, 2))
f = np.eye(3)
g = np.random.randint(1, 100, size=(3, 3))

print("Array a:", a)
print("Arange b:", b)
print("Linspace c:", c)
print("Zeros d:\n", d)
print("Ones e:\n", e)
print("Identity f:\n", f)
print("Random g:\n", g)
# Out:
# Array a: [1 2 3 4 5]
# Arange b: [1 3 5 7 9]
# Linspace c: [0.   0.25 0.5  0.75 1.  ]
# Zeros d:
#  [[0. 0. 0.]
#  [0. 0. 0.]]
# Ones e:
#  [[1. 1.]
#  [1. 1.]]
# Identity f:
#  [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# Random g:
#  [[90 46 86]
#  [84 55 79]
#  [33 77 66]]

# %%
# 2️⃣ Array Properties
print("\nShape:", g.shape)
print("Dimensions:", g.ndim)
print("Size:", g.size)
print("Data type:", g.dtype)
# Out:
# Shape: (3, 3)
# Dimensions: 2
# Size: 9
# Data type: int64

# %%
# 3️⃣ Reshape & Transpose
reshaped = g.reshape(1, 9)
print("\nReshaped array:", reshaped)
print("Transpose:\n", g.T)
print("Flattened:", g.flatten())
# Out:
# Reshaped array: [[90 46 86 84 55 79 33 77 66]]
# Transpose:
#  [[90 84 33]
#  [46 55 77]
#  [86 79 66]]
# Flattened: [90 46 86 84 55 79 33 77 66]

# %%
# 4️⃣ Mathematical Operations
print("\nAdd:", np.add(a, 2))
print("Multiply:", np.multiply(a, 3))
print("Square Root:", np.sqrt(a))
print("Power:", np.power(a, 2))
print("Absolute:", np.abs([-1, -2, 3]))
# Out:
# Add: [3 4 5 6 7]
# Multiply: [ 3  6  9 12 15]
# Square Root: [1.         1.41421356 1.73205081 2.         2.23606798]
# Power: [ 1  4  9 16 25]
# Absolute: [1 2 3]

# %%
# 5️⃣ Statistical Functions
print("\nMean:", np.mean(a))
print("Median:", np.median(a))
print("Standard Deviation:", np.std(a))
print("Variance:", np.var(a))
print("Minimum:", np.min(a))
print("Maximum:", np.max(a))
print("Sum:", np.sum(a))
print("Percentile (50):", np.percentile(a, 50))
# Out:
# Mean: 3.0
# Median: 3.0
# Standard Deviation: 1.4142135623730951
# Variance: 2.0
# Minimum: 1
# Maximum: 5
# Sum: 15
# Percentile (50): 3.0

# %%
# 6️⃣ Axis-based Operations
print("\nColumn-wise Sum:\n", np.sum(g, axis=0))
print("Row-wise Mean:\n", np.mean(g, axis=1))
# Out:
# Column-wise Sum:
#  [207 178 231]
# Row-wise Mean:
#  [74.         72.66666667 58.66666667]

# %%
# 7️⃣ Indexing & Slicing
print("\nFirst element:", a[0])
print("Slice:", a[1:4])
print("2D Slice:\n", g[0:2, 1:3])
# Out:
# First element: 1
# Slice: [2 3 4]
# 2D Slice:
#  [[46 86]
#  [55 79]]

# %%
# 8️⃣ Boolean & Conditional
print("\nWhere > 50:\n", np.where(g > 50))
print("Any > 90:", np.any(g > 90))
print("All > 0:", np.all(g > 0))
# Out:
# Where > 50:
#  (array([0, 0, 1, 1, 1, 2, 2]), array([0, 2, 0, 1, 2, 1, 2]))
# Any > 90: False
# All > 0: True

# %%
# 9️⃣ Sorting & Searching
print("\nSorted a:", np.sort(a))
print("Index of max:", np.argmax(a))
print("Index of min:", np.argmin(a))
print("Unique elements:", np.unique([1, 2, 2, 3, 4, 4]))
# Out:
# Sorted a: [1 2 3 4 5]
# Index of max: 4
# Index of min: 0
# Unique elements: [1 2 3 4]

# %%
# 🔟 Linear Algebra
x = np.array([[1, 2], [3, 4]])
y = np.array([[5, 6], [7, 8]])

print("\nDot Product:\n", np.dot(x, y))
print("Matrix Multiplication:\n", np.matmul(x, y))
print("Determinant:", np.linalg.det(x))
print("Inverse:\n", np.linalg.inv(x))
# Out:
# Dot Product:
#  [[19 22]
#  [43 50]]
# Matrix Multiplication:
#  [[19 22]
#  [43 50]]
# Determinant: -2.0000000000000004
# Inverse:
#  [[-2.   1. ]
#  [ 1.5 -0.5]]

# %%
# 1️⃣1️⃣ Random Functions
np.random.seed(1)
rand_sample = np.random.choice(a, size=3)
print("\nRandom Choice:", rand_sample)
# Out:
# Random Choice: [4 5 1]

# %%
# 1️⃣2️⃣ Stack & Concatenate
h1 = np.array([1, 2, 3])
h2 = np.array([4, 5, 6])

print("\nConcatenate:", np.concatenate((h1, h2)))
print("Vertical Stack:\n", np.vstack((h1, h2)))
print("Horizontal Stack:", np.hstack((h1, h2)))
# Out:
# Concatenate: [1 2 3 4 5 6]
# Vertical Stack:
#  [[1 2 3]
#  [4 5 6]]
# Horizontal Stack: [1 2 3 4 5 6]

# %%
# 1️⃣3️⃣ Save & Load
np.save("sample_array.npy", a)
loaded = np.load("sample_array.npy")
print("\nLoaded Array:", loaded)
# Out:
# Loaded Array: [1 2 3 4 5]

# %%
# A. Creating DataFrames



import pandas as pd



# From a Dictionary

data = {

'Name': ['Alice', 'Bob', 'Charlie'],

'Age': [25, 30, 35],

'City': ['New York', 'Paris', 'London']

}

df = pd.DataFrame(data)



# Viewing data

print(df.head())      # First 5 rows

print(df.info())      # Summary of data types and non-nulls

print(df.describe())  # Statistical summary (mean, std, min, max)
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30     Paris
# 2  Charlie   35    London
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes
# None
#         Age
# count   3.0
# mean   30.0
# std     5.0
# min    25.0
# 25%    27.5
# 50%    30.0
# 75%    32.5
# max    35.0

# %%
#B. Selection and Filtering
# Selecting a column
import pandas as pd
data ={
    'Name': ['Alice', 'Bob', 'Charile'],
    'Age': [25, 30, 35],
    'City': ['New york', 'Paris', 'london']
}
df = pd.DataFrame(data)
ages = df['Age']



# Filtering rows

above_30 = df[df['Age'] > 30]



# iloc (integer-based) vs loc (label-based)

row_0 = df.iloc[0]          # First row (Alice's data)

specific_val = df.loc[0, 'City'] # 'New York'

# %%
# Checking for nulls

print(df.isnull().sum())



# Dropping missing values

df_clean = df.dropna()



# Filling missing values

df_filled = df.fillna(0) # Fill NaNs with 0

# Or fill with mean:

# df['Age'] = df['Age'].fillna(df['Age'].mean())
# Out:
# Name    0
# Age     0
# City    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Create a new DataFrame with StudyHours and ExamScore columns
data = {
    'StudyHours': [10, 20, 15, 25, 30],
    'ExamScore': [60, 75, 70, 85, 90]
}
df_plot = pd.DataFrame(data)

# 1️⃣ Scatter Plot
# ----------------------------

plt.scatter(df_plot['StudyHours'], df_plot['ExamScore'])
plt.xlabel("Study Hours")
plt.ylabel("Exam Score")
plt.title("Study Hours vs Exam Score (Scatter Plot)")
plt.show()

# %%
# 2️⃣ Line Plot
# ----------------------------

plt.plot(df_plot['StudyHours'], df_plot['ExamScore'], marker='o')
plt.xlabel("Study Hours")
plt.ylabel("Exam Score")
plt.title("Exam Score Progress (Line Plot)")
plt.show()

# %%
# ----------------------------
# 3️⃣ Histogram
# ----------------------------

plt.hist(df_plot['ExamScore'], bins=5)
plt.xlabel("Score Range")
plt.ylabel("Number of Students")
plt.title("Exam Score Distribution (Histogram)")
plt.show()

# %%
# ----------------------------
# 4️⃣ Bar Chart
# ----------------------------

plt.bar(df_plot['StudyHours'], df_plot['ExamScore'])
plt.xlabel("Study Hours")
plt.ylabel("Exam Score")
plt.title("Study Hours vs Exam Score (Bar Chart)")
plt.show()

# %%
# STEP 1: IMPORT LIBRARIES

import pandas as pd

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_squared_error

# STEP 2: CREATE DATASET

data = {

'Student': ['S1','S2','S3','S4','S5','S6','S7','S8','S9','S10'],

'Classes_Attended': [30, 35, 40, 45, 50, 55, 60, 65, 70, 75],

'Internal_Marks': [35, 38, 42, 46, 50, 55, 60, 65, 70, 75]

}

df = pd.DataFrame(data)

print(df)

# STEP 3: FEATURES & TARGET

X = df[['Classes_Attended']]

y = df['Internal_Marks']

# STEP 4: TRAIN-TEST SPLIT

X_train, X_test, y_train, y_test = train_test_split(

X, y, test_size=0.2, random_state=7

)

# STEP 5: TRAIN MODEL

model = LinearRegression()

model.fit(X_train, y_train)

# STEP 6: PREDICTION

predictions = model.predict(X_test)

# STEP 7: EVALUATION

mse = mean_squared_error(y_test, predictions)

print("MSE:", mse)

print("Marks per Class:", model.coef_[0])

print("Base Marks:", model.intercept_)

# STEP 8: VISUALIZATION

plt.scatter(X, y)

plt.plot(X, model.predict(X))

plt.xlabel("Classes Attended")

plt.ylabel("Internal Marks")

plt.title("Classes Attended vs Internal Marks")

plt.show()
# Out:
#   Student  Classes_Attended  Internal_Marks
# 0      S1                30              35
# 1      S2                35              38
# 2      S3                40              42
# 3      S4                45              46
# 4      S5                50              50
# 5      S6                55              55
# 6      S7                60              60
# 7      S8                65              65
# 8      S9                70              70
# 9     S10                75              75
# MSE: 0.578125
# Marks per Class: 0.9
# Base Marks: 6.375
